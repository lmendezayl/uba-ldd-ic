# %%
import seaborn as sns
import seaborn.objects as so

from scipy import stats
import numpy as np

import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from formulaic import model_matrix

from sklearn import linear_model    # Herramientas de modelos lineales
from sklearn.metrics import mean_squared_error, r2_score    # Medidas de desempeño
from sklearn.preprocessing import PolynomialFeatures    # Herramientas de polinomios

# %%
def generar_datos(n=1000, amin=0, amax=20, bmin=5, bmax=20, seed=2906):
    np.random.seed(seed)
    brange = bmax - bmin
    a = stats.uniform.rvs(size=n, loc=amin, scale=amax - amin)
    b = stats.norm.rvs(size=n, loc=bmin + brange / 2, scale=brange / 8)
    eps = stats.norm.rvs(size=n, loc=0, scale=4)
    y = 1 + 3 * a - 2 * b + 1.5 * a * b - 0.8 * a**2 + 0.6 * b**2 + eps
    return pd.DataFrame({"a": a, "b": b}), pd.Series(y)


X, y = generar_datos()

# %%
X
# Out:
#              a          b
# 0     8.734133  15.394511
# 1    13.034632  12.525557
# 2    17.034105  10.551190
# 3    10.817888  15.382497
# 4     9.217678  13.748394
# ..         ...        ...
# 995   8.671706  12.553847
# 996   6.947835   8.640205
# 997   4.878641  14.271576
# 998  11.313032  16.268229
# 999  16.359204   9.781642
#
# [1000 rows x 2 columns]

# %%
y
# Out:
# 0      280.324677
# 1      216.688679
# 2      131.789786
# 3      303.421562
# 4      235.852460
#           ...
# 995    195.343680
# 996    102.264704
# 997    200.028047
# 998    333.430498
# 999    110.685708
# Length: 1000, dtype: float64

# %%
# Graficamos la variable respuesta en funcion de las explicativas, en dos gráficos separados

# %%
(
    so.Plot(x = X.a, y = y)
    .add(so.Dot())
)

# %%
(
    so.Plot(x = X.b, y = y)
    .add(so.Dot())
)

# %%
# Probamos primero un modelo lineal
test_split = 0.95
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_split)

# %%
modeloLineal1 = LinearRegression()
modeloLineal1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Guardamos los coeficientes en forma prolija
beta1 = pd.Series(modeloLineal1.coef_, index=X_train.columns)
beta1["intercept"] = modeloLineal1.intercept_
beta1
# Out:
# a              5.743446
# b             30.165530
# intercept   -250.365724
# dtype: float64

# %%
# Calculando el ECM en entrenamiento y testeo

# ECM train
y_pred = modeloLineal1.predict(X_train)
ecm = mean_squared_error(y_train, y_pred)
print('Raiz cuadarada del ECM en entrenamiento: ', np.sqrt(ecm))

# ECM test
y_pred = modeloLineal1.predict(X_test)
ecm = mean_squared_error(y_test, y_pred)
print('Raiz cuadarada del ECM en testeo: ', np.sqrt(ecm))
# Out:
# Raiz cuadarada del ECM en entrenamiento:  30.27463630210933
# Raiz cuadarada del ECM en testeo:  30.44695681268876

# %% [markdown]
# ## Análisis de residuos
#
# Llamamos residuo al error en la predicción, es decir la diferencia entre el valor real y el valor predicho (y - y_pred).
#
# Queremos ver si hay estructura en los residuos o parecen aleatorios.
#
# Si hay estructura significa que hay alguna relación que no estamos teniendo en cuenta en el modelo.

# %%
# Ponemos todo en un solo DataFrame
# Podemos usar también pd.concat, pero tenemos que tener cuidado con los índices!
df_test = X_test.copy()
df_test["y"] = y_test
df_test["y_pred"] = y_pred
df_test["resid"] = df_test["y"] - df_test["y_pred"]
df_test.head()
# Out:
#             a          b           y      y_pred      resid
# 928  0.035305  15.126378  110.858662  206.132257 -95.273595
# 233  8.245538  13.327013  216.979295  199.008478  17.970817
# 62   3.296314  11.122261  112.620254  104.075372   8.544882
# 996  6.947835   8.640205  102.264704   50.175162  52.089542
# 81   7.996455  14.233652  243.056966  224.927139  18.129827

# %%
# Residuos en función de y
(
    so.Plot(x = df_test.y, y = df_test.resid)
    .add(so.Dot())
)

# %%
# Esto nos muestra que estamos prediciendo por abajo en los valores grandes de y, pero no hay mucho que podamos hacer porque no conocemos y.

# %%
# Residuos en función de a
(
    so.Plot(x = df_test.a, y = df_test.resid)
    .add(so.Dot())
)

# %% [markdown]
# Que sugiere esto?
#
# Que los errores siguen una estructura tipo parabola.

# %%
# Residuos en función de b
(
    so.Plot(x = df_test.b, y = df_test.resid)
    .add(so.Dot())
)

# %%
# No vemos mucha estructura acá, o es más dificil de saber qué hacer a partir de estos residuos.

# %%
# Comenzamos por agregar un término cuadrático en a.
formula = "~ poly(a, 2) + b"  # Esto aplica una normalización para evitar valores muy grandes
X_train2 = model_matrix(formula, data= X_train)
X_train2.head()

# Hace que los vectores sean ortogonales??? ojtia
# Out:
#      Intercept  poly(a, 2)[1]  poly(a, 2)[2]          b
# 725        1.0       0.047224      -0.130919  13.774746
# 285        1.0       0.205975       0.161715   9.566928
# 466        1.0      -0.221671       0.216577   8.710858
# 458        1.0       0.019214      -0.144195  14.634917
# 279        1.0       0.034110      -0.138567  14.694275

# %%
# Ajustamos
modeloLineal2 = LinearRegression()
modeloLineal2.fit(X_train2, y_train)

# Calculando el ECM en entrenamiento

# ECM train
y_pred2 = modeloLineal2.predict(X_train2)
ecm = mean_squared_error(y_train, y_pred2)
print('Raiz cuadarada del ECM en entrenamiento: ', np.sqrt(ecm))
# Out:
# Raiz cuadarada del ECM en entrenamiento:  18.608885178444307

# %% [markdown]
# Pasamos de 30 a 18!

# %%
# Como calculamos las predicciones? Tenemos que aplicar la misma transformación en testeo!
# La salida de formulaic no es solo la matriz, tambien guarda información de la transforamción
X_train2.model_spec
# Out:
# ModelSpec(formula=1 + poly(a, 2) + b, materializer='pandas', materializer_params={}, ensure_full_rank=True, na_action=<NAAction.DROP: 'drop'>, output='pandas', cluster_by=<ClusterBy.NONE: 'none'>, structure=[EncodedTermStructure(term=1, scoped_terms=[1], columns=['Intercept']), EncodedTermStructure(term=poly(a, 2), scoped_terms=[poly(a, 2)], columns=['poly(a, 2)[1]', 'poly(a, 2)[2]']), EncodedTermStructure(term=b, scoped_terms=[b], columns=['b'])], transform_state={'poly(a, 2)': {'alpha': {0: np.float64(9.474076086021046), 1: np.float64(9.546505700137041)}, 'norms2': {1: np.float64(1618.1201149565222), 0: np.float64(50.0), 2: np.float64(48700.04418043807)}}}, encoder_state={'poly(a, 2)': (<Kind.NUMERICAL: 'numerical'>, {}), 'b': (<Kind.NUMERICAL: 'numerical'>, {})})

# %%
ms = X_train2.model_spec
# Tenemos que aplicar la misma transformacion de train en testeo, sino no dan ien las predicciones.

# %%
# Ahora podemos aplicar esas especificaciones a cualquier DataFrame! 
# En este caso seria un error aplicar la misma "fórmula", necesitamos aplicar las mismas transformaciones
X_test2 = ms.get_model_matrix(X_test)
X_test2
# Out:
#      Intercept  poly(a, 2)[1]  poly(a, 2)[2]          b
# 928        1.0      -0.234644       0.260157  15.126378
# 233        1.0      -0.030541      -0.139405  13.327013
# 62         1.0      -0.153577       0.028321  11.122261
# 996        1.0      -0.062801      -0.116900   8.640205
# 81         1.0      -0.036733      -0.136269  14.233652
# ..         ...            ...            ...        ...
# 25         1.0       0.211994       0.180083  12.496378
# 659        1.0       0.035257      -0.137999  10.774004
# 601        1.0      -0.135581      -0.010072  14.837027
# 889        1.0       0.010255      -0.146012  10.311655
# 240        1.0      -0.010542      -0.145694  13.199799
#
# [950 rows x 4 columns]

# %%
# Ahora si podemos calcular las predicciones en testeo
# Calculando el ECM en testeo
y_pred2 = modeloLineal2.predict(X_test2)
ecm = mean_squared_error(y_test, y_pred2)
print('Raiz cuadarada del ECM en testeo: ', np.sqrt(ecm))
# Out:
# Raiz cuadarada del ECM en testeo:  18.101649314370384

# %% [markdown]
# Es parecido al que teniamos en train, pero pasamos de 30 a 18 de test a test.

# %%
# Analizamos nuevamente los residuos

# %%
df_test2 = X_test.copy()
df_test2["y"] = y_test # No necesitamos las variables generadas
df_test2["y_pred"] = y_pred2
df_test2["resid"] = df_test2["y"] - df_test2["y_pred"]
df_test2.head()
# Out:
#             a          b           y      y_pred      resid
# 928  0.035305  15.126378  110.858662  151.103573 -40.244911
# 233  8.245538  13.327013  216.979295  220.612340  -3.633045
# 62   3.296314  11.122261  112.620254  103.636815   8.983440
# 996  6.947835   8.640205  102.264704   83.948024  18.316680
# 81   7.996455  14.233652  243.056966  242.834034   0.222932

# %%
# Residuos en función de a
(
    so.Plot(x = df_test2.a, y = df_test2.resid)
    .add(so.Dot())
)

# %%
# Residuos en función de b
(
    so.Plot(x = df_test2.b, y = df_test2.resid)
    .add(so.Dot())
)

# %%
# Agregamos interacciones
# Comenzamos por agregar un término cuadrático en a.
formula = "~ poly(a, 2) * b"  # Esto aplica una normalización para evitar valores muy grandes
X_train3 = model_matrix(formula, data= X_train)
X_train3.head()
# Recordar que la columna poly(a, 2)[1]:b es simplemente poly(a, 2)[1] por b
# Aca tenemos el intercept, las cosas del polinomio de grado 2 de a, b, y las interacciones del poli con b.
# Out:
#      Intercept  poly(a, 2)[1]  poly(a, 2)[2]          b  poly(a, 2)[1]:b  \
# 725        1.0       0.047224      -0.130919  13.774746         0.650499
# 285        1.0       0.205975       0.161715   9.566928         1.970549
# 466        1.0      -0.221671       0.216577   8.710858        -1.930941
# 458        1.0       0.019214      -0.144195  14.634917         0.281197
# 279        1.0       0.034110      -0.138567  14.694275         0.501227
#
#      poly(a, 2)[2]:b
# 725        -1.803382
# 285         1.547116
# 466         1.886570
# 458        -2.110277
# 279        -2.036141

# %%
# Ajustamos
modeloLineal3 = LinearRegression()
modeloLineal3.fit(X_train3, y_train)

# Calculando el ECM en entrenamiento

# ECM train
y_pred3 = modeloLineal3.predict(X_train3)
ecm = mean_squared_error(y_train, y_pred3)
print('Raiz cuadarada del ECM en entrenamiento: ', np.sqrt(ecm))
# Out:
# Raiz cuadarada del ECM en entrenamiento:  4.913223817048092

# %%
# Calculamos el ECM en testeo
# Guardamos la transformacion que haya hecho Formulaic en ms de nuevo, para aplicarlo en testeo
ms = X_train3.model_spec

# Generamos la matriz
X_test3 = ms.get_model_matrix(X_test)
X_test3.head()
# Out:
#      Intercept  poly(a, 2)[1]  poly(a, 2)[2]          b  poly(a, 2)[1]:b  \
# 928        1.0      -0.234644       0.260157  15.126378        -3.549319
# 233        1.0      -0.030541      -0.139405  13.327013        -0.407020
# 62         1.0      -0.153577       0.028321  11.122261        -1.708122
# 996        1.0      -0.062801      -0.116900   8.640205        -0.542617
# 81         1.0      -0.036733      -0.136269  14.233652        -0.522846
#
#      poly(a, 2)[2]:b
# 928         3.935231
# 233        -1.857858
# 62          0.314988
# 996        -1.010038
# 81         -1.939609

# %%
# ECM test
y_pred3 = modeloLineal3.predict(X_test3)
ecm = mean_squared_error(y_test, y_pred3)
print('Raiz cuadarada del ECM en testeo: ', np.sqrt(ecm))
# Out:
# Raiz cuadarada del ECM en testeo:  4.939816932828776

# %%
df_test3 = X_test.copy()
df_test3["y"] = y_test # No necesitamos las variables generadas
df_test3["y_pred"] = y_pred3
df_test3["resid"] = df_test3["y"] - df_test3["y_pred"]
df_test3.head()
# Out:
#             a          b           y      y_pred     resid
# 928  0.035305  15.126378  110.858662  109.263562  1.595100
# 233  8.245538  13.327013  216.979295  217.799284 -0.819989
# 62   3.296314  11.122261  112.620254  110.567786  2.052469
# 996  6.947835   8.640205  102.264704   92.281895  9.982809
# 81   7.996455  14.233652  243.056966  238.396043  4.660922

# %%
# Residuos en función de a
(
    so.Plot(x = df_test3.a, y = df_test3.resid)
    .add(so.Dot())
)

# %%
# Residuos en función de b
(
    so.Plot(x = df_test3.b, y = df_test3.resid)
    .add(so.Dot())
)

# %% [markdown]
# Podemos seguir agregando términos e interacciones de mayor grado. Vamos a hacer regresión Ridge para evitar el sobreajuste.

# %%
from sklearn.linear_model import Ridge

# Cuando uno hace Ridge, tenemos que sacar el intercept, porque es la forma correcta no penalizar al intercept.
# Si hubiera intercept, cuando llamamos sklearn no se da cuenta, entonces lo penalizaria.
# Si lo penaliza, el modelo tomaria alfas 0. (Preguntar, no entendi muy bien)
formula = "~ poly(a, 4) * poly(b, 4) - 1"
X_train4 = model_matrix(formula, data=X_train)
ms = X_train4.model_spec
X_train4
# Out:
#      poly(a, 4)[1]  poly(a, 4)[2]  poly(a, 4)[3]  poly(a, 4)[4]  \
# 725       0.047224      -0.130919      -0.053448       0.107771
# 285       0.205975       0.161715      -0.018728      -0.188118
# 466      -0.221671       0.216577      -0.227397       0.191538
# 458       0.019214      -0.144195       0.010669       0.142032
# 279       0.034110      -0.138567      -0.024041       0.128602
# 759      -0.013957      -0.145035       0.087114       0.131082
# 591       0.122108      -0.038931      -0.160108      -0.116689
# 973       0.133751      -0.017242      -0.161313      -0.153928
# 959       0.185840       0.104133      -0.088468      -0.231739
# 898      -0.038951      -0.135009       0.137581       0.088039
# 433      -0.142825      -0.013412       0.150706      -0.164819
# 553       0.155908       0.041547      -0.120621      -0.142277
# 863      -0.114137      -0.052083       0.149738      -0.089084
# 200      -0.025296      -0.112607       0.053863       0.111821
# 840      -0.216055       0.127645       0.042340      -0.224005
# 152      -0.060473      -0.099352       0.103763       0.050655
# 631       0.103065      -0.041889      -0.118651       0.000387
# 38        0.176344       0.082310      -0.101157      -0.189745
# 218      -0.098579      -0.069151       0.141515      -0.045841
# 845       0.079078      -0.069307      -0.098463       0.057221
# 797       0.123298      -0.013686      -0.127224      -0.053915
# 877      -0.040336      -0.108658       0.076415       0.089916
# 541      -0.295983       0.351048      -0.327222       0.302639
# 382      -0.208458       0.110183       0.062455      -0.233823
# 558       0.092307      -0.054993      -0.110804       0.027212
# 677       0.027752      -0.106046      -0.030259       0.129242
# 843      -0.091748      -0.075776       0.136439      -0.027160
# 564      -0.048421      -0.105474       0.087858       0.075417
# 495      -0.092753      -0.074835       0.137238      -0.029885
# 756       0.041274      -0.099267      -0.050548       0.118184
# 322      -0.114422      -0.051745       0.149842      -0.089875
# 271       0.013018      -0.111071      -0.007120       0.134172
# 72        0.095252      -0.051536      -0.113159       0.020059
# 530       0.261957       0.304582       0.148038      -0.147551
# 687      -0.052152      -0.103755       0.092941       0.068136
# 187       0.324406       0.519171       0.549191       0.409480
# 605      -0.083073      -0.083428       0.128832      -0.004071
# 656       0.097130      -0.049280      -0.114582       0.015417
# 609       0.031286      -0.104475      -0.035669       0.126947
# 165       0.211362       0.163174      -0.035014      -0.234947
# 377       0.179101       0.088171      -0.097517      -0.195246
# 828      -0.107000      -0.060254       0.146571      -0.069212
#
#      poly(a, 4)[1]:poly(b, 4)[1]  poly(a, 4)[2]:poly(b, 4)[1]  ...  \
# 725                     0.004396                    -0.012187  ...
# 285                    -0.046573                    -0.036565  ...
# 466                     0.064517                    -0.063035  ...
# 458                     0.003042                    -0.022832  ...
# 279                     0.005555                    -0.022565  ...
# 759                    -0.000190                    -0.001974  ...
# 591                     0.005185                    -0.001653  ...
# 973                     0.009394                    -0.001211  ...
# 959                     0.004687                     0.002626  ...
# 898                     0.010271                     0.035601  ...
# 122                    -0.000078                     0.000274  ...
# 645                     0.000716                    -0.006046  ...
# 723                     0.018478                    -0.003889  ...
# 900                     0.014270                    -0.005442  ...
# 318                    -0.011664                    -0.007577  ...
# 674                     0.000251                    -0.004665  ...
# 849                    -0.004022                     0.010987  ...
# 642                    -0.042029                    -0.053548  ...
# 433                    -0.023422                    -0.006909  ...
# 553                    -0.013947                    -0.013531  ...
# 863                    -0.008429                     0.012285  ...
# 200                     0.005452                    -0.004978  ...
# 840                     0.037455                    -0.016420  ...
# 152                    -0.013855                    -0.014225  ...
# 631                     0.005133                    -0.013307  ...
# 38                     -0.034466                     0.023989  ...
# 218                     0.012173                     0.003273  ...
# 845                     0.009211                    -0.003851  ...
# 797                     0.007080                    -0.015194  ...
# 877                     0.005626                     0.000087  ...
# 541                     0.060696                    -0.048660  ...
# 382                    -0.024390                     0.009968  ...
# 558                     0.008083                    -0.008453  ...
# 677                    -0.003347                    -0.001067  ...
# 843                    -0.002723                     0.012898  ...
# 564                    -0.000101                     0.007101  ...
# 495                    -0.000060                     0.013603  ...
# 756                    -0.004828                    -0.001848  ...
# 322                    -0.029884                    -0.040054  ...
# 271                    -0.002666                     0.002129  ...
# 72                     -0.021773                     0.022813  ...
# 530                     0.061530                     0.066744  ...
# 687                     0.008641                    -0.002964  ...
# 187                    -0.044235                    -0.002763  ...
# 605                     0.017054                    -0.013714  ...
# 656                     0.015845                     0.004500  ...
# 609                    -0.002734                    -0.002800  ...
# 165                     0.017369                    -0.020760  ...
# 377                    -0.008480                    -0.023209  ...
# 828                    -0.009601                     0.009501  ...
#
#      poly(a, 4)[3]:poly(b, 4)[2]  poly(a, 4)[4]:poly(b, 4)[2]  \
# 725                     0.002891                    -0.005828
# 285                    -0.002842                    -0.028549
# 466                    -0.076216                     0.064197
# 458                     0.000492                     0.006556
# 279                    -0.001319                     0.007054
# 759                    -0.009662                    -0.014539
# 591                     0.015782                     0.011502
# 973                     0.012545                     0.011970
# 959                     0.009474                     0.024816
# 898                     0.034680                     0.022192
# 122                     0.003954                    -0.013872
# 645                    -0.001537                    -0.014153
# 723                    -0.003135                    -0.002678
# 900                    -0.006152                     0.013449
# 318                    -0.005655                     0.002807
# 674                    -0.003891                    -0.015069
# 849                     0.004510                    -0.008805
# 642                     0.006249                     0.005208
# 433                     0.001827                     0.003006
# 553                     0.008144                    -0.002335
# 863                     0.005540                    -0.002239
# 200                     0.020380                    -0.013491
# 840                     0.007235                    -0.019474
# 152                    -0.009515                     0.005476
# 631                     0.002473                    -0.004303
# 38                     -0.004202                    -0.004345
# 218                    -0.012701                     0.010322
# 845                     0.010926                     0.006774
# 797                     0.001027                    -0.001180
# 877                    -0.017240                     0.019014
# 541                    -0.038376                     0.006638
# 382                    -0.017400                    -0.010962
# 558                     0.007057                    -0.000031
# 677                    -0.019809                     0.015158
# 843                     0.001046                    -0.010137
# 564                    -0.005358                    -0.015124
# 495                    -0.004053                    -0.010687
# 756                    -0.018871                     0.013349
# 322                    -0.016717                    -0.016999
# 271                     0.011942                    -0.001838
# 72                      0.014607                    -0.014636
# 530                     0.039759                    -0.001520
# 687                    -0.008933                     0.017578
# 187                     0.085474                    -0.088959
# 605                     0.009242                    -0.001738
# 656                     0.006780                     0.010985
# 609                    -0.020395                     0.005197
# 165                    -0.019617                     0.002903
# 377                     0.013406                     0.005997
# 828                     0.007915                     0.000392
#
#      poly(a, 4)[1]:poly(b, 4)[3]  poly(a, 4)[2]:poly(b, 4)[3]  \
# 725                    -0.005263                     0.014590
# 285                     0.002492                     0.001956
# 466                     0.065418                    -0.063915
# 458                    -0.002286                     0.017155
# 279                    -0.003938                     0.015998
# 759                     0.000112                     0.001169
# 591                    -0.006383                     0.002035
# 973                    -0.011872                     0.001530
# 959                    -0.004895                    -0.002743
# 898                     0.005474                     0.018974
# 122                     0.000660                    -0.002313
# 645                    -0.000879                     0.007422
# 723                    -0.016252                     0.003420
# 900                    -0.021975                     0.008381
# 318                     0.012797                     0.008313
# 674                    -0.000288                     0.005352
# 72                     -0.005685                     0.005697
# 530                    -0.019261                     0.000736
# 687                     0.005866                    -0.011543
# 187                     0.067415                    -0.070164
# 605                     0.000451                    -0.000085
# 656                    -0.002121                    -0.003437
# 609                     0.024781                    -0.006314
# 165                     0.028246                    -0.004179
# 377                    -0.029686                    -0.013281
# 828                     0.009092                     0.000451
#
# [50 rows x 24 columns]

# %%
# Generamos un vector de alfas
alfas = np.logspace(-7, 4, 61)
alfas
# Out:
# array([1.00000000e-07, 1.52522296e-07, 2.32630507e-07, 3.54813389e-07,
#        5.41169527e-07, 8.25404185e-07, 1.25892541e-06, 1.92014194e-06,
#        2.92864456e-06, 4.46683592e-06, 6.81292069e-06, 1.03912230e-05,
#        1.58489319e-05, 2.41731548e-05, 3.68694506e-05, 5.62341325e-05,
#        8.57695899e-05, 1.30817747e-04, 1.99526231e-04, 3.04321989e-04,
#        4.64158883e-04, 7.07945784e-04, 1.07977516e-03, 1.64689787e-03,
#        2.51188643e-03, 3.83118685e-03, 5.84341413e-03, 8.91250938e-03,
#        1.35935639e-02, 2.07332157e-02, 3.16227766e-02, 4.82317848e-02,
#        7.35642254e-02, 1.12201845e-01, 1.71132830e-01, 2.61015722e-01,
#        3.98107171e-01, 6.07202196e-01, 9.26118728e-01, 1.41253754e+00,
#        2.15443469e+00, 3.28599325e+00, 5.01187234e+00, 7.64422274e+00,
#        1.16591440e+01, 1.77827941e+01, 2.71227258e+01, 4.13682040e+01,
#        6.30957344e+01, 9.62350626e+01, 1.46779927e+02, 2.23872114e+02,
#        3.41454887e+02, 5.20794833e+02, 7.94328235e+02, 1.21152766e+03,
#        1.84784980e+03, 2.81838293e+03, 4.29866235e+03, 6.55641849e+03,
#        1.00000000e+04])

# %%
X_test4 = ms.get_model_matrix(X_test)

rmse_train = {}  # Resulta útil guardar los valores en un diccionario
rmse_test = {}
intercept = {}
for alfa in alfas:
    ridge = Ridge(alpha=alfa)
    ridge.fit(X_train4, y_train)
    rmse_train[alfa] =  np.sqrt(mean_squared_error(ridge.predict(X_train4), y_train))
    rmse_test[alfa] =  np.sqrt(mean_squared_error(ridge.predict(X_test4), y_test))
    intercept[alfa] = ridge.intercept_

# %%
# Convertimos a DataFrame para graficar
data = pd.DataFrame(
    {
        "rmse_train": rmse_train,
        "rmse_test": rmse_test,
        "intercept": intercept,
    }
).reset_index(names="alfa")
data
# Out:
#             alfa  rmse_train  rmse_test   intercept
# 0   1.000000e-07    3.364600  54.678571  181.886205
# 1   1.525223e-07    3.364600  54.657275  181.886807
# 2   2.326305e-07    3.364601  54.624830  181.887722
# 3   3.548134e-07    3.364603  54.575428  181.889115
# 4   5.411695e-07    3.364607  54.500273  181.891232
# ..           ...         ...        ...         ...
# 56  1.847850e+03   73.179180  68.807885  182.552887
# 57  2.818383e+03   73.195276  68.821180  182.552814
# 58  4.298662e+03   73.205833  68.829900  182.552767
# 59  6.556418e+03   73.212757  68.835619  182.552736
# 60  1.000000e+04   73.217298  68.839370  182.552716
#
# [61 rows x 4 columns]

# %%
# Residuos en función de a
(
    so.Plot(data = data, x= "alfa").scale(x = "log")
    .add(so.Line(), y = "rmse_train")
    .add(so.Line(color = "red"), y = "rmse_test")
)

# %% [markdown]
# Cuando alfa es 0 es el mejor ajuste claramente, pero metemos el alfa y la primera vez no sabemos como afecta.
# Claramente a mas aumenta el alfa, mas importancia se le da a los $\beta$ entonce el error en testeo es peor.
#
# Con este grafico podemos ver que hay un alfa entre $10^{-4}$ y $10^{-3}$ que mas o menos minimiza el error.

# %% [markdown]
# Notas:
# - Ridge es regularizacion con norma-2.
# - Lasso es regularizacion Ridge con norma-1.
# - Elastic Net es regularizar sumando Ridge y Lasso.

# %%
# Automatizamos la búsqueda con comandos de sklearn

# %%
# La primera opción es usar GridSearch
# Este metodo es general tanto para Ridge, Lasso, Elastic Net, etc...

# %%
from sklearn.model_selection import GridSearchCV

alfas = np.logspace(-7, 1, 61)

param_grid = {"alpha": alfas}
gs = GridSearchCV(
    Ridge(),
    param_grid,
    cv=5,
    scoring="neg_root_mean_squared_error",
    return_train_score=True,
)
gs.fit(X_train4, y_train)

gs.best_params_
# Out:
# {'alpha': np.float64(0.004641588833612782)}

# %%
# O podemos usar validazion cruzada específica de Ridge
# Este es propio de sklearn

# %%
modelo = linear_model.RidgeCV(alphas = alfas, cv = 5) #cv es la cantidad de pliegos para Cross Validation
modelo.fit(X_train4, y_train)
modelo.alpha_ #modelo.alpha_ devuelve el mejor alfa asumo xd
# Out:
# np.float64(0.00630957344480193)

# %%
# ECM train
y_pred = modelo.predict(X_train4)
ecm = mean_squared_error(y_train, y_pred)
print('Raiz cuadarada del ECM en entrenamiento: ', np.sqrt(ecm))

# ECM test
y_pred = modelo.predict(X_test4)
ecm = mean_squared_error(y_test, y_pred)
print('Raiz cuadarada del ECM en testeo: ', np.sqrt(ecm))
# Out:
# Raiz cuadarada del ECM en entrenamiento:  5.451549452702157
# Raiz cuadarada del ECM en testeo:  16.040922792387875

# %%
(
    so.Plot(x = np.arange(len(modelo.coef_)))
    .add(so.Dot(color = "r"), y = modelo.coef_)
)

# %%
# Miramos los coeficientes en forma prolija
# Trucazo
beta1 = pd.Series(modelo.coef_, index=X_train4.columns)
beta1["intercept"] = modelo.intercept_
beta1
# Out:
# poly(a, 4)[1]                  251.653574
# poly(a, 4)[2]                 -180.337270
# poly(a, 4)[3]                   -6.361335
# poly(a, 4)[4]                    1.146740
# poly(b, 4)[1]                  353.628321
# poly(b, 4)[2]                   38.920650
# poly(b, 4)[3]                   -9.438755
# poly(b, 4)[4]                   20.895507
# poly(a, 4)[1]:poly(b, 4)[1]    495.033985
# poly(a, 4)[2]:poly(b, 4)[1]     39.424643
# poly(a, 4)[3]:poly(b, 4)[1]    -58.963670
# poly(a, 4)[4]:poly(b, 4)[1]     -9.850133
# poly(a, 4)[1]:poly(b, 4)[2]     54.242796
# poly(a, 4)[2]:poly(b, 4)[2]     95.268164
# poly(a, 4)[3]:poly(b, 4)[2]    -12.541478
# poly(a, 4)[4]:poly(b, 4)[2]    123.535640
# poly(a, 4)[1]:poly(b, 4)[3]    -29.106466
# poly(a, 4)[2]:poly(b, 4)[3]     87.252156
# poly(a, 4)[3]:poly(b, 4)[3]      2.782401
# poly(a, 4)[4]:poly(b, 4)[3]     60.724368
# poly(a, 4)[1]:poly(b, 4)[4]     80.488881
# poly(a, 4)[2]:poly(b, 4)[4]     30.033537
# poly(a, 4)[3]:poly(b, 4)[4]    -31.727286
# poly(a, 4)[4]:poly(b, 4)[4]    -25.810991
# intercept                      182.594243
# dtype: float64

# %%
# O podemos usar Leave-One-Out
# En este esquema, la cantidad de pliegos es igual a la cantidad de observaciones!
modelo = linear_model.RidgeCV(alphas = alfas)
modelo.fit(X_train4, y_train)
modelo.alpha_
# Out:
# np.float64(0.001)

# %%
# ECM train
y_pred = modelo.predict(X_train4)
ecm = mean_squared_error(y_train, y_pred)
print('Raiz cuadarada del ECM en entrenamiento: ', np.sqrt(ecm))

# ECM test
y_pred = modelo.predict(X_test4)
ecm = mean_squared_error(y_test, y_pred)
print('Raiz cuadarada del ECM en testeo: ', np.sqrt(ecm))
# Out:
# Raiz cuadarada del ECM en entrenamiento:  3.911192645753072
# Raiz cuadarada del ECM en testeo:  11.822469338009276

# %%
modelo.coef_
# Out:
# array([ 254.52099754, -176.89319176,   -4.70681835,    5.58497252,
#         358.50965651,   35.35533381,   -0.87047485,   17.45430678,
#         698.42435886,  -29.23479441,  -63.78518538,  -11.74766217,
#          40.86365844,   53.85889188,   27.11559217,  135.91817425,
#           2.81434343,   54.97687432,  -34.85025308,   61.21343836,
#          96.23564699,  -29.73780368,   43.57930846,  -47.23997166])

# %%
(
    so.Plot(x = np.arange(len(modelo.coef_)))
    .add(so.Dot(color = "r"), y = modelo.coef_)
)

# %%
# Miramos los coeficientes en forma prolija
beta1 = pd.Series(modelo.coef_, index=X_train4.columns)
beta1["intercept"] = modelo.intercept_
beta1
# Out:
# poly(a, 4)[1]                  254.520998
# poly(a, 4)[2]                 -176.893192
# poly(a, 4)[3]                   -4.706818
# poly(a, 4)[4]                    5.584973
# poly(b, 4)[1]                  358.509657
# poly(b, 4)[2]                   35.355334
# poly(b, 4)[3]                   -0.870475
# poly(b, 4)[4]                   17.454307
# poly(a, 4)[1]:poly(b, 4)[1]    698.424359
# poly(a, 4)[2]:poly(b, 4)[1]    -29.234794
# poly(a, 4)[3]:poly(b, 4)[1]    -63.785185
# poly(a, 4)[4]:poly(b, 4)[1]    -11.747662
# poly(a, 4)[1]:poly(b, 4)[2]     40.863658
# poly(a, 4)[2]:poly(b, 4)[2]     53.858892
# poly(a, 4)[3]:poly(b, 4)[2]     27.115592
# poly(a, 4)[4]:poly(b, 4)[2]    135.918174
# poly(a, 4)[1]:poly(b, 4)[3]      2.814343
# poly(a, 4)[2]:poly(b, 4)[3]     54.976874
# poly(a, 4)[3]:poly(b, 4)[3]    -34.850253
# poly(a, 4)[4]:poly(b, 4)[3]     61.213438
# poly(a, 4)[1]:poly(b, 4)[4]     96.235647
# poly(a, 4)[2]:poly(b, 4)[4]    -29.737804
# poly(a, 4)[3]:poly(b, 4)[4]     43.579308
# poly(a, 4)[4]:poly(b, 4)[4]    -47.239972
# intercept                      182.548034
# dtype: float64
